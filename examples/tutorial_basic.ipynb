# %%
from anndata import read_h5ad

# %%
adata_mi = read_h5ad("/home/malte/Dokumente/Github/microarray/examples/data/anca_sum.h5ad")
adata_mi
# Out:
# /home/malte/Dokumente/Github/dtangle/.venv/lib/python3.11/site-packages/anndata/_core/anndata.py:1825: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# AnnData object with n_obs × n_vars = 6 × 18227
#     obs: 'sample_name', 'cel_version', 'nrows', 'ncols', 'algorithm', 'condition', 'celfile'
#     var: 'gene_id', 'n_probes', 'converged'
#     uns: 'X_pca', 'normalization', 'summarization'
#     obsm: 'X_pca'

# %%
from dtangle import deconvolut

# %%
deconvolut(
    adata_mi[0, :].X,
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 deconvolut(
#       2     adata_mi[0, :].X,
#       3 )
#
# File ~/Dokumente/Github/dtangle/src/dtangle/_deconvolution.py:69, in deconvolut(Y, references, pure_samples, n_markers, data_type, gamma, markers, marker_method, summary_fn, layer, var_key, key_added, copy)
#      66 y_in = extract_input(Y, layer=layer, var_key=var_key)
#      67 ref_in = extract_input(references, layer=layer, var_key=var_key) if references is not None else None
# ---> 69 prepared, pure_input_rows = combine_inputs(y_in, ref_in, pure_samples)
#      71 marker_list, marker_counts = process_markers(
#      72     prepared.y,
#      73     prepared.pure_samples,
#    (...)     79     gamma=gamma,
#      80 )
#      82 baseline = baseline_exprs(prepared.y, prepared.pure_samples, marker_list, summary_fn=summary_fn)
#
# ...
